# %% [markdown]
# Data Preprocceing

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("EastWestAirlines.csv")

# %%
data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
data.isnull()
# Out:
#         ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     False    False       False      False      False      False
# 1     False    False       False      False      False      False
# 2     False    False       False      False      False      False
# 3     False    False       False      False      False      False
# 4     False    False       False      False      False      False
# ...     ...      ...         ...        ...        ...        ...
# 3994  False    False       False      False      False      False
# 3995  False    False       False      False      False      False
# 3996  False    False       False      False      False      False
# 3997  False    False       False      False      False      False
# 3998  False    False       False      False      False      False
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0           False        False              False            False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
data=data.drop(['ID#'],axis=1)

# %%
def box(i):
    plt.boxplot(data[i])
    plt.show()

# %%
box('Balance')

# %%
data.describe()
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %%
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans(n_clusters=5).fit(data)
model.inertia_
# Out:
# 5750368606964.947

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.cluster import KMeans
fig=plt.figure(figsize=(8,4))
WCSS=[]
for i in range(1,11):
  model=KMeans(n_clusters=i).fit(data)
  WCSS.append(model.inertia_)
plt.plot(range(1,11),WCSS)
plt.title("The Elbow Method")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# clf=KMeans(n_clusters=5)
# clf.fit(data)

# %%
clf=KMeans(n_clusters=5)
clf.fit(data)
# Out:
# KMeans(n_clusters=5)

# %%
y_names=clf.predict(data)

# %%
y_names
# Out:
# array([1, 1, 1, ..., 4, 1, 1])

# %%
clf.labels_
# Out:
# array([1, 1, 1, ..., 4, 1, 1])

# %%
md=pd.DataFrame(y_names)
data['clust']=md
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
data.clust.value_counts()
# Out:
# clust
# 1    2534
# 4    1041
# 2     331
# 0      83
# 3      10
# Name: count, dtype: int64

# %% [raw]
# here there is total 5 clusters divided data:
# clust
# 1    2534
# 4    1041
# 2     331
# 0      83
# 3      10

# %% [markdown]
# Here KMean is done we let's do it with DBSCAN

# %%
df=pd.read_csv("EastWestAirlines.csv")

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
array=df.values

# %%
std=StandardScaler().fit(array)

# %%
x=std.transform(array)

# %%
x
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
dbscan=DBSCAN(eps=2.3,min_samples=12)
dbscan.fit(x)
# Out:
# DBSCAN(eps=2.3, min_samples=12)

# %%
cl=pd.DataFrame(dbscan.labels_,columns=['cluster'])

# %%
cl
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 3994        0
# 3995        0
# 3996        0
# 3997        0
# 3998        0
#
# [3999 rows x 1 columns]

# %%
df=pd.concat([df,cl],axis=1)

# %%
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.cluster.value_counts()
# Out:
# cluster
#  0    3762
# -1     216
#  1      21
# Name: count, dtype: int64

# %% [raw]
# now here in cluster 0 there are total 3762 points are there :core points
# -1 indecates outliers\noise in data here total 216 :outliers point\noise points
# in cluster 1 there is total 21 :boundry point

# %% [markdown]
# now here we get a balanced points so this those values we used as eps,min_samples was appropriate

# %% [raw]
# Here’s a quick comparison of K-Means and DBSCAN:
#
# - **K-Means**: It partitions data into a predefined number of clusters (k). Each point belongs to the cluster with the nearest mean (centroid). It's fast but struggles with non-spherical clusters or varying densities. Outliers may distort results.
#
# - **DBSCAN**: It groups points based on density, requiring no predefined number of clusters. It's great for identifying clusters of varying shapes and densities and can label outliers as noise. However, choosing the right parameters (`eps` and `minPts`) is crucial.
#
# In essence, K-Means works best for structured, evenly distributed data, while DBSCAN is versatile for complex patterns and outliers.
